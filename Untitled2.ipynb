# %% [markdown]
# <a href="https://colab.research.google.com/github/navadeepjinugu/CSA0703/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler

# Generate linearly separable data
X, y = make_classification(n_samples=100,
                           n_features=2,
                           n_redundant=0,
                           n_clusters_per_class=1,
                           class_sep=2)

y = np.where(y == 0, -1, 1)

X = StandardScaler().fit_transform(X)

weights = np.random.randn(2) * 0.01
bias = 0
lr = 0.1

for epoch in range(20):
    errors = 0

    for xi, target in zip(X, y):
        output = np.sign(np.dot(xi, weights) + bias)

        if output != target:
            weights += lr * target * xi
            bias += lr * target
            errors += 1

    print(f"Epoch {epoch+1}, Errors = {errors}")

    if errors == 0:
        print("Converged!")
        break

print("Weights:", weights)
print("Bias:", bias)
# Out:
# Epoch 1, Errors = 6
# Epoch 2, Errors = 1
# Epoch 3, Errors = 0
# Converged!
# Weights: [-0.0376204  -0.43209694]
# Bias: -0.1
